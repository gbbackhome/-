# %% [markdown]
# # **회귀 분석 모델 만들기**

# %% [markdown]
# # Dummy variables

# %% [markdown]
# ## Import the relevant libraries

# %%
#import the necessary libraries

# %% [markdown]
# ## Load the data

# %%
#loading the data either from google colab

# %%
#pd.read_csv

# %%
#head

# %%
#describe

# %%
#unique
#value_counts()

# %% [markdown]
# ## Map the data

# %%
#.copy

# %%
#.map

# %% [markdown]
# ## Regression

# %%
#sm.add
#sm.OLS.fit
#results.summary()

# %% [markdown]
# # Insights
# If you actually compare with the OLS without attendance, the model improved:
#
# R-sqaured: 0.406 -> 0.565
#
# Adj R: 0.399 -> 0.555
#
# F-STAT: 56.05 -> 52.70
#
# constant P: 0.503 -> 0.076
#
# SAT: 0.00 -> 0.00
#
# Attendance: 0.00

# %% [markdown]
# ## Plot the regression line(s) on the scatter plot

# %% [markdown]
# ## The calculation behind
#
# yhat_no:
# GPA = 0.6439 + 0.0014 * SAT + 0.2226 * Dummy
#
# ***GPA = 0.6439 + 0.0014 * SAT***
#
# yhat_yes:
# GPA = 0.6439 + 0.0014 * SAT + 0.2226
# GPA = 0.8665 + 0.0014 * SAT

# %%
#plt.scatter
#insert line
#plt.plot
#plt.xlabel, ylabel

# %% [markdown]
# ## Plot the regression line(s) on the scatter plot and colour the data points

# %%
#plt.scatter with added color on dots: c=, cmap=
#c=data['Attendance] 는 함수는 각 점에 색상을 넣는다
#cmap = 'RdYlGn_r' 함수는 어떤 색상을 넣을지 설정한다

# %% [markdown]
# ## Add the original regression line for comparison

# %%
#plt.scatter
#add original line

# %% [markdown]
# # How to make predictions based on the regression we create
#
# EX:
#
# Bob, who got 1700 on the SAT and did not attend
#
# Alice, who got 1670 on the SAT and attended

# %%
#use pd.DataFrame of Bob and Alice

# %%
#data.rename of index

# %%
#.predict()

# %%
#add predicted value to the original DataFrame
#use .join()
#.rename to adjust index
